# %%
import matplotlib.pyplot as plt 
import numpy as np 
import torch 
import model

# %%
N = 100
f = 5
dt = 0.0001
T = 10

# %%
w_ins = 0.1**(torch.arange(100,110)/10)
means = torch.zeros(w_ins.size(0))
for i in range(w_ins.size(0)):
  w_in = w_ins[i]
  spikes = model.run(N,f,dt,T,w_in)
  means[i] = spikes.sum(0).mean()
# Out:
#   1%|          | 941/99999 [00:16<29:40, 55.62it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 for i in range(w_ins.size(0)):
#       4   w_in = w_ins[i]
# ----> 5   spikes = model.run(N,f,dt,T,w_in)
#       6   means[i] = spikes.sum(0).mean()
#
# File ~/Desktop/NeuroProject/model.py:96, in run(N, f, dt, T, w_in)
#      93 t = step * dt
#      95 dU = U_dot(t, U) * dt
# ---> 96 dV = V_dot(V, t, U, spikes) * dt
#      98 U[:, step + 1, :] = U[:, step, :] + dU
#     100 V += dV * Switch
#
# File ~/Desktop/NeuroProject/model.py:77, in run.<locals>.V_dot(V, t, U, spikes)
#      76 def V_dot(V, t, U, spikes):
# ---> 77     return -(V - V_r) / (R * C) + get_I_ext(t) / C + get_I_in(t, U, spikes) / C
#
# File ~/Desktop/NeuroProject/model.py:70, in run.<locals>.get_I_in(t, U, spikes)
#      64 fired = torch.zeros((N, time_steps), device=device, dtype=dtype)
#      65 fired[:, :step] = spikes[:, :step]
#      66 gate = torch.sum(
#      67     torch.exp((-(t - t_span * spikes) / tau_s) * fired)
#      68     * fired
#      69     * torch.heaviside(
# ---> 70         opening - eta, torch.zeros_like(eta, device=device, dtype=dtype)
#      71     ).sum(2),
#      72     dim=1,
#      73 )
#      74 return w_in * A @ gate
#
# KeyboardInterrupt:

# %%
plt.plot((w_ins),(means))

# %%
plt.plot(np.log10(w_ins),np.log10(means))
