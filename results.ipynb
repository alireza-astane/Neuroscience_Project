# %%
import matplotlib.pyplot as plt 
import numpy as np 
import torch 
import model

# %%
N = 100
f = 5
dt = 0.0001
T = 1

# %%
w_ins = 0.1**(torch.arange(100,110)/10)
means = torch.zeros(w_ins.size(0))
for i in range(w_ins.size(0)):
  w_in = w_ins[i]
  spikes = model.run(N,f,dt,T,w_in)
  means[i] = spikes.sum(0).mean()
# Out:
#   7%|▋         | 742/9999 [00:03<00:40, 230.14it/s]

# %%
w_ins = 0.1**(torch.arange(200,220)/20)
w_ins*10**12
# Out:
# tensor([100.0000,  89.1251,  79.4328,  70.7946,  63.0958,  56.2341,  50.1187,
#          44.6683,  39.8108,  35.4814,  31.6228,  28.1838,  25.1188,  22.3872,
#          19.9526,  17.7828,  15.8489,  14.1254,  12.5893,  11.2202])

# %%
plt.plot((w_ins),(means))

# %%
plt.plot(np.log10(w_ins),np.log10(means))

# %%
spikes = model.run(100,5,dt,1,50*10**-12)
# Out:
# 100%|██████████| 9999/9999 [00:43<00:00, 229.26it/s]

# %%
spikes.sum()
# Out:
# tensor(54522., device='cuda:0', dtype=torch.float64)

# %%
plt.scatter(np.arange(spikes.sum(0).shape[0]),spikes.sum(0).cpu())
